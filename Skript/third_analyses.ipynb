# %%
import pandas as pd
import seaborn as sns
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # Wir gucken die Gene die 3,4,5 Disease haben (unwichtig eher)

# %%
df_1=pd.read_csv("choosen_disease_2_5_most_final.csv")

# %%
df_1
# Out:
#      Disease_ID  Gene_ID
# 0      C0236969    10207
# 1      C0236969   114788
# 2      C0236969   121601
# 3      C0236969   140733
# 4      C0236969    23345
# ...         ...      ...
# 1062   C0007621     6667
# 1063   C0007621   693223
# 1064   C0007621     7852
# 1065   C0007621     8848
# 1066   C0007621     9076
#
# [1067 rows x 2 columns]

# %%
df_1["Disease_ID"].value_counts()
# Out:
# C1458155    68
# C0033578    66
# C0024668    50
# C0024667    46
# C0027627    39
# C0038356    38
# C2239176    35
# C0017661    34
# C0031117    33
# C0009404    31
# C0151744    31
# C0027626    30
# C0014175    29
# C0003873    27
# C0242656    25
# C0028754    24
# C0024121    23
# C0007131    21
# C0007621    21
# C0036341    21
# C0004352    21
# C0376634    19
# C3714756    17
# C0011860    17
# C0025202    17
# C0011853    16
# C0000786    15
# C0001418    15
# C0010606    15
# C0007134    14
# C0002395    13
# C0860207    13
# C0236969    13
# C0019693    13
# C0009375    13
# C0032460    13
# C0021390    12
# C0020538    12
# C0023893    12
# C0005695    11
# C3495559    11
# C0023467    10
# C0021368     9
# C0030567     9
# C0026769     9
# C0004096     9
# C0010346     8
# C0023903     8
# C0236736     6
# C0919267     5
# Name: Disease_ID, dtype: int64

# %%
df_1["Gene_ID"].value_counts()
# Out:
# 2180     5
# 898      5
# 26227    5
# 4321     5
# 4319     5
#         ..
# 2771     3
# 4254     3
# 4256     3
# 5045     3
# 5167     3
# Name: Gene_ID, Length: 323, dtype: int64

# %%
sns.set(rc={'figure.figsize':(12,8)})
sns.countplot(y="Disease_ID", data=df_1, palette="coolwarm",
              order=df_1.Disease_ID.value_counts().iloc[:40].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Disease_ID'>

# %%
sns.set(rc={'figure.figsize':(12,8)})
sns.countplot(y="Gene_ID", data=df_1, palette="coolwarm",
              order=df_1.Gene_ID.value_counts().iloc[:40].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Gene_ID'>

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Disease_ID  1067 non-null   object
#  1   Gene_ID     1067 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 16.8+ KB

# %%
df_1.nunique()
#50 Diseases
#323 Gene
# Out:
# Disease_ID     50
# Gene_ID       323
# dtype: int64

# %% [markdown]
# # Wir gucken die Gene die  4,5 Disease haben

# %%
df_2=pd.read_csv("choosen_disease_4_5_most_final.csv")

# %%
df_2
# Out:
#     Disease_ID  Gene_ID
# 0     C0236969     4897
# 1     C0236969     9547
# 2     C0003873    10125
# 3     C0003873     4319
# 4     C0003873     4321
# ..         ...      ...
# 351   C0007621     3476
# 352   C0007621     3852
# 353   C0007621   406984
# 354   C0007621   407021
# 355   C0007621     7852
#
# [356 rows x 2 columns]

# %%
df_2["Disease_ID"].value_counts()
# Out:
# C1458155    28
# C0033578    22
# C0024668    18
# C0038356    17
# C0024667    15
# C0027626    15
# C0027627    14
# C2239176    12
# C0007131    12
# C0031117    12
# C0007621    10
# C0024121    10
# C0014175     9
# C0009404     9
# C0004352     9
# C0151744     8
# C0242656     8
# C0017661     7
# C0011853     7
# C0025202     7
# C0007134     6
# C0023467     6
# C0000786     6
# C0032460     6
# C0003873     5
# C0010606     5
# C0009375     5
# C3714756     5
# C0028754     5
# C0376634     5
# C0011860     5
# C0023903     4
# C0036341     4
# C0004096     4
# C0005695     4
# C0001418     4
# C0030567     4
# C0020538     3
# C0860207     3
# C0023893     3
# C0919267     3
# C0021390     2
# C0236969     2
# C0002395     2
# C0026769     2
# C0236736     2
# C3495559     1
# C0019693     1
# Name: Disease_ID, dtype: int64

# %%
df_2["Gene_ID"].value_counts()
# Out:
# 2886    5
# 1789    5
# 898     5
# 5618    5
# 2180    5
#        ..
# 5947    4
# 5315    4
# 5037    4
# 4072    4
# 2026    4
# Name: Gene_ID, Length: 86, dtype: int64

# %%
sns.set(rc={'figure.figsize':(12,8)})
sns.countplot(y="Disease_ID", data=df_2, palette="coolwarm",
              order=df_2.Disease_ID.value_counts().iloc[:40].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Disease_ID'>

# %%
sns.set(rc={'figure.figsize':(12,8)})
sns.countplot(y="Gene_ID", data=df_2, palette="coolwarm",
              order=df_2.Gene_ID.value_counts().iloc[:40].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Gene_ID'>

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356 entries, 0 to 355
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Disease_ID  356 non-null    object
#  1   Gene_ID     356 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.7+ KB

# %%
df_2.nunique() # 48 Disease und 86 Gene
# Out:
# Disease_ID    48
# Gene_ID       86
# dtype: int64

# %% [markdown]
# # Wir gucken die Gene die genau mit 5 disease verbunden sind

# %%
df_3=pd.read_csv("choosen_disease_5_6_most_final.csv")

# %%
df_3
# Out:
#    Disease_ID  Gene_ID
# 0    C0003873    10125
# 1    C0003873     4319
# 2    C0003873     4321
# 3    C0023893     2690
# 4    C0024667     2180
# 5    C0024667     5618
# 6    C0024667     7170
# 7    C0024668     2180
# 8    C0024668     5618
# 9    C0024668     7170
# 10   C0024668     8648
# 11   C0033578     1789
# 12   C0033578    26227
# 13   C0033578     2690
# 14   C0033578     2886
# 15   C0033578     8648
# 16   C0004352     2690
# 17   C0004352     5618
# 18   C0001418     2886
# 19   C0001418     7170
# 20   C2239176      898
# 21   C0151744     2690
# 22   C0031117    10125
# 23   C0031117     2690
# 24   C0376634     1789
# 25   C0242656      898
# 26   C0000786     4321
# 27   C0000786     5618
# 28   C0027627     4319
# 29   C0027627     8648
# 30   C0009375     4321
# 31   C0009375     7170
# 32   C0024121     2886
# 33   C0024121     4319
# 34   C1458155     1789
# 35   C1458155    26227
# 36   C1458155     2886
# 37   C1458155     8648
# 38   C1458155      898
# ...

# %%
df_3["Disease_ID"].value_counts()
# Out:
# C1458155    5
# C0033578    5
# C0024668    4
# C0038356    3
# C0014175    3
# C0003873    3
# C0024667    3
# C0001418    2
# C0031117    2
# C0000786    2
# C0027627    2
# C0009375    2
# C0024121    2
# C0004352    2
# C0017661    2
# C0007134    1
# C0919267    1
# C0021390    1
# C0028754    1
# C0011853    1
# C0011860    1
# C0007131    1
# C0002395    1
# C0023467    1
# C0005695    1
# C2239176    1
# C0004096    1
# C0025202    1
# C0023893    1
# C0242656    1
# C0376634    1
# C0151744    1
# C0007621    1
# Name: Disease_ID, dtype: int64

# %%
df_3["Gene_ID"].value_counts()
# Out:
# 10125    5
# 4319     5
# 4321     5
# 2690     5
# 2180     5
# 5618     5
# 7170     5
# 8648     5
# 1789     5
# 26227    5
# 2886     5
# 898      5
# Name: Gene_ID, dtype: int64

# %%
sns.set(rc={'figure.figsize':(12,8)})
sns.countplot(y="Disease_ID", data=df_3, palette="coolwarm",
              order=df_3.Disease_ID.value_counts().iloc[:40].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Disease_ID'>

# %%
sns.set(rc={'figure.figsize':(12,8)})
sns.countplot(y="Gene_ID", data=df_3, palette="coolwarm",
              order=df_3.Gene_ID.value_counts().iloc[:40].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Gene_ID'>

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Disease_ID  60 non-null     object
#  1   Gene_ID     60 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.1+ KB

# %%
df_3.nunique() #33 Disease und 12 Gene
# Out:
# Disease_ID    33
# Gene_ID       12
# dtype: int64

# %% [markdown]
# # Create the Disease network for DF 3 (5 Gene) for cytoscape

# %%
df_3
# Out:
#    Disease_ID  Gene_ID
# 0    C0003873    10125
# 1    C0003873     4319
# 2    C0003873     4321
# 3    C0023893     2690
# 4    C0024667     2180
# 5    C0024667     5618
# 6    C0024667     7170
# 7    C0024668     2180
# 8    C0024668     5618
# 9    C0024668     7170
# 10   C0024668     8648
# 11   C0033578     1789
# 12   C0033578    26227
# 13   C0033578     2690
# 14   C0033578     2886
# 15   C0033578     8648
# 16   C0004352     2690
# 17   C0004352     5618
# 18   C0001418     2886
# 19   C0001418     7170
# 20   C2239176      898
# 21   C0151744     2690
# 22   C0031117    10125
# 23   C0031117     2690
# 24   C0376634     1789
# 25   C0242656      898
# 26   C0000786     4321
# 27   C0000786     5618
# 28   C0027627     4319
# 29   C0027627     8648
# 30   C0009375     4321
# 31   C0009375     7170
# 32   C0024121     2886
# 33   C0024121     4319
# 34   C1458155     1789
# 35   C1458155    26227
# 36   C1458155     2886
# 37   C1458155     8648
# 38   C1458155      898
# ...

# %%
df_disease_network=pd.DataFrame(columns=["Source_Disease","Target_Disease"])
grouped = df_3.groupby('Disease_ID') #Gene_ID
for name, group in grouped:
    #print(group)
    print(name)
    related_gene=group["Gene_ID"].to_list() #Disease_ID
    for elem in related_gene:
        related_disease=df_3[df_3["Gene_ID"]== elem]["Disease_ID"].to_list() #tauschen
        print(related_disease)
        
        
        for elem_disease in related_disease:
            #A ->B but not B-> or B->A but not A->B
            probe=df_disease_network[(df_disease_network['Source_Disease']==elem_disease)&
                                     (df_disease_network['Target_Disease'] == name)]
            print(probe)
            if probe.empty and (name!=elem_disease): # if (name!=elem_disease): bei plot
                
                df_disease_network.loc[len(df_disease_network)]=[name, elem_disease]
                
df_disease_network=df_disease_network.drop_duplicates()
        
        
        
    
    
    


#skip_Disease=[]
#for index,row in df_3.iterrows():
    #Disease,Gene= row["Disease_ID"],row["Gene_ID"]
# Out:
# C0000786
# ['C0003873', 'C0000786', 'C0009375', 'C0002395', 'C0017661']
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# ['C0024667', 'C0024668', 'C0004352', 'C0000786', 'C0014175']
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# C0001418
# ['C0033578', 'C0001418', 'C0024121', 'C1458155', 'C0007134']
# Empty DataFrame
# ...

# %%
#df_disease_network.drop(df_disease_network.index[df_disease_network['Source_Disease'] ==df_disease_network['Target_Disease'] ], inplace=True)

# %%
df_disease_network
# Out:
#     Source_Disease Target_Disease
# 0         C0000786       C0003873
# 1         C0000786       C0009375
# 2         C0000786       C0002395
# 3         C0000786       C0017661
# 4         C0000786       C0024667
# ..             ...            ...
# 115       C0242656       C0919267
# 116       C0376634       C1458155
# 117       C0919267       C2239176
# 118       C0919267       C1458155
# 119       C1458155       C2239176
#
# [114 rows x 2 columns]

# %%
df_disease_network.to_csv("df_disease_network_5_cyto.csv",index=False) # loops löschen

# %% [markdown]
# #  Create the Gene network for DF 3 (5 Gene) Cyto

# %%
df_gene_network=pd.DataFrame(columns=["Source_Gene","Target_Gene"])
grouped = df_3.groupby('Gene_ID') #Gene_ID
for name, group in grouped:
    #print(group)
    print(name)
    related_disease=group["Disease_ID"].to_list() #Disease_ID
    for elem in related_disease:
        related_gene=df_3[df_3["Disease_ID"]== elem]["Gene_ID"].to_list() #tauschen
        print(related_gene)
        
        
        for elem_gene in related_gene:
            #A ->B but not B-> or B->A but not A->B
            probe=df_gene_network[(df_gene_network['Source_Gene']==elem_gene)&
                                     (df_gene_network['Target_Gene'] == name)]
            print(probe)
            if probe.empty and (name!=elem_gene): # if (name!=elem_disease): bei plot
                
                df_gene_network.loc[len(df_gene_network)]=[name, elem_gene]
                
df_gene_network=df_gene_network.drop_duplicates()
# Out:
# 898
# [898]
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# [898]
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# [1789, 26227, 2886, 8648, 898]
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# [898]
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# [898]
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# 1789
# [1789, 26227, 2690, 2886, 8648]
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# ...

# %%
#df_Gene_network.drop(df_Gene_network.index[df_Gene_network['Source_Gene'] ==df_Gene_network['Target_Gene'] ], inplace=True)

# %%
df_gene_network.to_csv("df_gene_network_5_cyto.csv",index=False)

# %%
df_gene_network.head(39)
# Out:
#    Source_Gene Target_Gene
# 0          898        1789
# 1          898       26227
# 2          898        2886
# 3          898        8648
# 4         1789       26227
# 5         1789        2690
# 6         1789        2886
# 7         1789        8648
# 11        1789        4319
# 12        1789        7170
# 13        2180        5618
# 14        2180        7170
# 17        2180        8648
# 18        2180        4321
# 19        2690       26227
# 20        2690        2886
# 21        2690        8648
# 22        2690        5618
# 23        2690       10125
# 24        2886       26227
# 25        2886        8648
# 26        2886        7170
# 27        2886        4319
# 30        4319       10125
# 31        4319        4321
# 32        4319        8648
# 33        4319        7170
# 34        4321       10125
# 35        4321        5618
# 36        4321        7170
# 37        5618        7170
# 39        5618        8648
# 40        5618       10125
# ...

# %% [markdown]
# #  Create the Disease network  for DF 3 (5 Gene) for heatmap

# %%
df_disease_network=pd.DataFrame(columns=["Source_Disease","Target_Disease"])
grouped = df_3.groupby('Disease_ID') #Gene_ID
for name, group in grouped:
    #print(group)
    print(name)
    related_gene=group["Gene_ID"].to_list() #Disease_ID
    for elem in related_gene:
        related_disease=df_3[df_3["Gene_ID"]== elem]["Disease_ID"].to_list() #tauschen
        print(related_disease)
        
        
        for elem_disease in related_disease:
            #A ->B but not B-> or B->A but not A->B
            probe=df_disease_network[(df_disease_network['Source_Disease']==elem_disease)&
                                     (df_disease_network['Target_Disease'] == name)]
            print(probe)
            if (name!=elem_disease): # if (name!=elem_disease): bei plot
                
                df_disease_network.loc[len(df_disease_network)]=[name, elem_disease]
                
df_disease_network=df_disease_network.drop_duplicates()
# Out:
# C0000786
# ['C0003873', 'C0000786', 'C0009375', 'C0002395', 'C0017661']
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# ['C0024667', 'C0024668', 'C0004352', 'C0000786', 'C0014175']
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# C0001418
# ['C0033578', 'C0001418', 'C0024121', 'C1458155', 'C0007134']
# Empty DataFrame
# ...

# %%
df_disease_network.to_csv("df_disease_network_5_heat.csv",index=False)

# %% [markdown]
# #   Create the Gene network  for DF 3 (5 Gene) for heatmap

# %%
df_gene_network=pd.DataFrame(columns=["Source_Gene","Target_Gene"])
grouped = df_3.groupby('Gene_ID') #Gene_ID
for name, group in grouped:
    #print(group)
    print(name)
    related_disease=group["Disease_ID"].to_list() #Disease_ID
    for elem in related_disease:
        related_gene=df_3[df_3["Disease_ID"]== elem]["Gene_ID"].to_list() #tauschen
        print(related_gene)
        
        
        for elem_gene in related_gene:
            #A ->B but not B-> or B->A but not A->B
            probe=df_gene_network[(df_gene_network['Source_Gene']==elem_gene)&
                                     (df_gene_network['Target_Gene'] == name)]
            print(probe)
            if (name!=elem_gene): # if (name!=elem_disease): bei plot
                
                df_gene_network.loc[len(df_gene_network)]=[name, elem_gene]
                
df_gene_network=df_gene_network.drop_duplicates()
# Out:
# 898
# [898]
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# [898]
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# [1789, 26227, 2886, 8648, 898]
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# [898]
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# [898]
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# 1789
# [1789, 26227, 2690, 2886, 8648]
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# ...

# %%
df_gene_network.to_csv("df_gene_network_5_heat.csv",index=False)

# %% [markdown]
# #   Create the Disease network for DF 2 (4-5 Gene) Cyto

# %%
df_disease_network=pd.DataFrame(columns=["Source_Disease","Target_Disease"])
grouped = df_2.groupby('Disease_ID') #Gene_ID
for name, group in grouped:
    #print(group)
    print(name)
    related_gene=group["Gene_ID"].to_list() #Disease_ID
    for elem in related_gene:
        related_disease=df_2[df_2["Gene_ID"]== elem]["Disease_ID"].to_list() #tauschen
        print(related_disease)
        
        
        for elem_disease in related_disease:
            #A ->B but not B-> or B->A but not A->B
            probe=df_disease_network[(df_disease_network['Source_Disease']==elem_disease)&
                                     (df_disease_network['Target_Disease'] == name)]
            print(probe)
            if probe.empty and (name!=elem_disease): # if (name!=elem_disease): bei plot
                
                df_disease_network.loc[len(df_disease_network)]=[name, elem_disease]
                
df_disease_network=df_disease_network.drop_duplicates()
# Out:
# C0000786
# ['C0033578', 'C0000786', 'C0024121', 'C1458155']
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# ['C0026769', 'C0031117', 'C0000786', 'C0024121']
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# ['C0033578', 'C0000786', 'C0027626', 'C0027627']
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# ...

# %%
df_disease_network.to_csv("df_disease_network_4_5_cyto.csv",index=False)

# %% [markdown]
# # Create the Gene network for DF 2 (4-5 Gene) Cyto

# %%
df_gene_network=pd.DataFrame(columns=["Source_Gene","Target_Gene"])
grouped = df_2.groupby('Gene_ID') #Gene_ID
for name, group in grouped:
    #print(group)
    print(name)
    related_disease=group["Disease_ID"].to_list() #Disease_ID
    for elem in related_disease:
        related_gene=df_2[df_2["Disease_ID"]== elem]["Gene_ID"].to_list() #tauschen
        print(related_gene)
        
        
        for elem_gene in related_gene:
            #A ->B but not B-> or B->A but not A->B
            probe=df_gene_network[(df_gene_network['Source_Gene']==elem_gene)&
                                     (df_gene_network['Target_Gene'] == name)]
            print(probe)
            if probe.empty and (name!=elem_gene): # if (name!=elem_disease): bei plot
                
                df_gene_network.loc[len(df_gene_network)]=[name, elem_gene]
                
df_gene_network=df_gene_network.drop_duplicates()
# Out:
# 226
# [1000, 226, 2690, 3397, 3659, 5037, 5160, 811]
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# [10481, 2057, 226, 3400, 3732, 3945, 406984, 4504, 51129, 5315, 57016, 7291, 811, 8434, 9846]
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# ...

# %%
df_gene_network.to_csv("df_gene_network_4_5_cyto.csv",index=False)

# %% [markdown]
# # Create the Disease network for DF 2 (4-5 Gene) Heat

# %%
df_disease_network=pd.DataFrame(columns=["Source_Disease","Target_Disease"])
grouped = df_2.groupby('Disease_ID') #Gene_ID
for name, group in grouped:
    #print(group)
    print(name)
    related_gene=group["Gene_ID"].to_list() #Disease_ID
    for elem in related_gene:
        related_disease=df_2[df_2["Gene_ID"]== elem]["Disease_ID"].to_list() #tauschen
        print(related_disease)
        
        
        for elem_disease in related_disease:
            #A ->B but not B-> or B->A but not A->B
            probe=df_disease_network[(df_disease_network['Source_Disease']==elem_disease)&
                                     (df_disease_network['Target_Disease'] == name)]
            print(probe)
            if (name!=elem_disease): # if (name!=elem_disease): bei plot
                
                df_disease_network.loc[len(df_disease_network)]=[name, elem_disease]
                
df_disease_network=df_disease_network.drop_duplicates()
# Out:
# C0000786
# ['C0033578', 'C0000786', 'C0024121', 'C1458155']
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# ['C0026769', 'C0031117', 'C0000786', 'C0024121']
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# ['C0033578', 'C0000786', 'C0027626', 'C0027627']
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# Columns: [Source_Disease, Target_Disease]
# Index: []
# Empty DataFrame
# ...

# %%
df_disease_network.to_csv("df_disease_network_4_5_heat.csv",index=False)

# %% [markdown]
# # Create the Gene network for DF 2 (4-5 Gene) Heat

# %%
df_gene_network=pd.DataFrame(columns=["Source_Gene","Target_Gene"])
grouped = df_2.groupby('Gene_ID') #Gene_ID
for name, group in grouped:
    #print(group)
    print(name)
    related_disease=group["Disease_ID"].to_list() #Disease_ID
    for elem in related_disease:
        related_gene=df_2[df_2["Disease_ID"]== elem]["Gene_ID"].to_list() #tauschen
        print(related_gene)
        
        
        for elem_gene in related_gene:
            #A ->B but not B-> or B->A but not A->B
            probe=df_gene_network[(df_gene_network['Source_Gene']==elem_gene)&
                                     (df_gene_network['Target_Gene'] == name)]
            print(probe)
            if (name!=elem_gene): # if (name!=elem_disease): bei plot
                
                df_gene_network.loc[len(df_gene_network)]=[name, elem_gene]
                
df_gene_network=df_gene_network.drop_duplicates()
# Out:
# 226
# [1000, 226, 2690, 3397, 3659, 5037, 5160, 811]
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# [10481, 2057, 226, 3400, 3732, 3945, 406984, 4504, 51129, 5315, 57016, 7291, 811, 8434, 9846]
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# Columns: [Source_Gene, Target_Gene]
# Index: []
# Empty DataFrame
# ...

# %%
df_gene_network.to_csv("df_gene_network_4_5_heat.csv",index=False)

# %% [markdown]
# # Zusatz

# %% [markdown]
# #   Create the Gene network for DF 3 (5 Gene)

# %%
df_Gene_network=pd.DataFrame(columns=["Source_Gene","Target_Gene"])
grouped = df_2.groupby('Gene_ID') #Gene_ID
for name, group in grouped:
    #print(group)
    print(name)
    related_gene=group["Disease_ID"].to_list() #Disease_ID
    for elem in related_gene:
        related_disease=df_2[df_2["Disease_ID"]== elem]["Gene_ID"].to_list()
        print(related_disease)
        
        
        for elem_disease in related_disease:
            df_Gene_network.loc[len(df_Gene_network)]=[name, elem_disease]
# Out:
# 226
# [1000, 226, 2690, 3397, 3659, 5037, 5160, 811]
# [10481, 2057, 226, 3400, 3732, 3945, 406984, 4504, 51129, 5315, 57016, 7291, 811, 8434, 9846]
# [1000, 1436, 2057, 226, 3732, 4319, 51129, 5268, 5478, 7291, 7852, 8434, 8648, 9846]
# [10457, 10481, 11009, 1436, 1474, 1789, 1902, 2057, 226, 26227, 2886, 3161, 3476, 3925, 3945, 406984, 407021, 4504, 4897, 51129, 5268, 5655, 5997, 6194, 6423, 6514, 8648, 898]
# 358
# [2309, 284058, 358, 3852, 64324]
# [2180, 3400, 358, 3852, 3925, 4072, 5037, 5315, 5618, 5685, 5947, 6277, 6319, 7170, 7227]
# [2180, 3397, 3400, 358, 3852, 3925, 4072, 5037, 5315, 5618, 5685, 5947, 6277, 6319, 7170, 7227, 780, 8648]
# [10451, 358, 5997]
# 563
# [10451, 10481, 11009, 1474, 1789, 1902, 26227, 2690, 2886, 3732, 3925, 3945, 4072, 4074, 5160, 563, 655, 6715, 780, 811, 8648, 9817]
# [2886, 563, 7170, 780]
# [1645, 1646, 3161, 563, 6241, 6715]
# [1066, 11009, 1591, 2886, 3476, 3659, 4319, 563, 780, 9547]
# 655
# [2690, 5105, 655]
# ...

# %%
df_Gene_network.drop(df_Gene_network.index[df_Gene_network['Source_Gene'] ==df_Gene_network['Target_Gene'] ], inplace=True)
df_Gene_network
# Out:
#      Source_Gene Target_Gene
# 0            226        1000
# 2            226        2690
# 3            226        3397
# 4            226        3659
# 5            226        5037
# ...          ...         ...
# 4144      407021       30061
# 4145      407021        3476
# 4146      407021        3852
# 4147      407021      406984
# 4149      407021        7852
#
# [3794 rows x 2 columns]

# %%
df_Gene_network.to_csv("df_gene_network_4_5.csv",index=False)
